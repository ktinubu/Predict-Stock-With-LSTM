# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.models import Sequential
import lstm, time

# %%
#loading the Data.
X_train, y_train, X_test, y_test = lstm.load_data('sp500_5_features.csv', 50, True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-21b41fc9fbe6> in <module>()
#       1 #loading the Data.
# ----> 2 X_train, y_train, X_test, y_test = lstm.load_data('sp500_5_features.csv', 50, True)
#
# ~/learning-deep-learning/spx_lstm/lstm.py in load_data(filename, seq_len, normalise_window)
#      25
#      26     if normalise_window:
# ---> 27         result = normalise_windows(result)
#      28
#      29     result = np.array(result)
#
# ~/learning-deep-learning/spx_lstm/lstm.py in normalise_windows(window_data)
#      45     normalised_data = []
#      46     for window in window_data:
# ---> 47         normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
#      48         normalised_data.append(normalised_window)
#      49     return normalised_data
#
# ~/learning-deep-learning/spx_lstm/lstm.py in <listcomp>(.0)
#      45     normalised_data = []
#      46     for window in window_data:
# ---> 47         normalised_window = [((float(p) / float(window[0])) - 1) for p in window]
#      48         normalised_data.append(normalised_window)
#      49     return normalised_data
#
# ValueError: could not convert string to float: '2251.570068,2263.879883,2245.129883,2257.830078,2257.830078,3770530000,'

# %%
#building Model
model = Sequential()

model.add(LSTM(input_dim=1,
               output_dim=50,
               return_sequences=True))

model.add(Dropout(0.2))

model.add(LSTM(100, return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(
            output_dim=1))
model.add(Activation('linear'))

start = time.time()
model.compile(loss='mse', optimizer='rmsprop')

print('compilation time:', time.time() - start)
# Out:
# compilation time: 0.03061389923095703

# %%
#Train the model
model.fit(
    X_train,
    y_train,
    batch_size=512,
    nb_epoch=1,
    validation_split=0.05)
# Out:
# Train on 3522 samples, validate on 186 samples
# Epoch 1/1
# 3522/3522 [==============================] - 7s - loss: 0.0024 - val_loss: 6.0171e-04

# %%
print(lstm.plot_results_multiple)
# Out:
# <function plot_results_multiple at 0x113f64598>

# %%
#plot results
predictions = lstm.predict_sequences_multiple(model, X_test, 50, 50)
lstm.plot_results_multiple(predictions, y_test, 50)
